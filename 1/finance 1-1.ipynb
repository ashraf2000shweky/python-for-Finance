# %%
import pandas as pd
import datetime as dt
import numpy as np
 # parse_dates تقوم بتحليل الفترة الزمنية أي مثلاً إذا كانت سلسلة نصية تصبح فترة زمنية  
df = pd.read_csv('AAPL.csv', parse_dates=['Date'],index_col='Date')
pd.options.display.float_format = '{:.2f}'.format

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2014-09-29 100.59 100.69  98.04  99.62      93.51  142718700
# 2014-10-06  99.95 102.38  98.31 100.73      94.56  280258200
# 2014-10-13 101.33 101.78  95.18  97.67      91.68  358539800
# 2014-10-20  98.32 105.49  98.22 105.22      98.77  358532900
# 2014-10-27 104.85 108.04 104.70 108.00     101.38  220230600

# %%
df.index.max()
# Out:
# Timestamp('2018-03-29 00:00:00')

# %%
df.index.min()
# Out:
# Timestamp('2014-09-29 00:00:00')

# %%
df_2017 = df[df.index.year == 2017]
df_2017
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2017-01-02 115.80 118.16 114.76 117.91     115.57  103845500
# 2017-01-09 117.95 119.93 117.94 119.04     116.68  138810700
# 2017-01-16 118.34 120.50 118.22 120.00     117.62  116348000
# 2017-01-23 120.00 122.44 119.50 121.95     119.53  124539300
# 2017-01-30 120.93 130.49 120.62 129.08     126.52  249781200
# 2017-02-06 129.13 132.94 128.90 132.12     129.50  136449200
# 2017-02-13 133.08 136.27 132.75 135.72     133.61  136667500
# 2017-02-20 136.23 137.48 135.28 136.66     134.53   87908900
# 2017-02-27 137.14 140.28 136.28 139.78     137.60  127474000
# 2017-03-06 139.37 139.98 137.05 139.14     136.97   99672200
# 2017-03-13 138.85 141.02 138.82 139.99     137.81  121539600
# 2017-03-20 140.40 142.80 139.73 140.64     138.45  129674000
# 2017-03-27 139.39 144.50 138.62 143.66     141.42  127008900
# 2017-04-03 143.71 145.46 143.05 143.34     141.11  105416200
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
sn.barplot(x=df.index.year,y=df['Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
sn.barplot(x=df_2017.index.month,y=df_2017['Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
pd.options.display.float_format = '{:.2f}'.format
df.loc['2017-06':'2018-01']
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2017-06-05 154.34 155.98 146.02 148.98     147.27  159159700
# 2017-06-12 145.74 147.50 142.20 142.27     140.63  220530400
# 2017-06-19 143.66 147.16 143.66 146.28     144.60  133253000
# 2017-06-26 147.17 148.28 142.28 144.02     142.36  127060200
# 2017-07-03 144.88 145.30 142.41 144.18     142.52   79158400
# 2017-07-10 144.11 149.33 143.37 149.04     147.32  111088400
# 2017-07-17 148.82 151.74 148.57 150.27     148.54  106081600
# 2017-07-24 150.58 153.99 147.30 149.50     147.78  105818100
# 2017-07-31 149.90 159.75 148.13 156.39     154.59  172808500
# 2017-08-07 157.06 161.83 154.63 157.48     155.67  151269100
# 2017-08-14 159.32 162.51 156.72 157.50     156.30  134628500
# 2017-08-21 157.50 160.74 155.11 159.86     158.64  112671200
# 2017-08-28 160.14 164.94 159.93 164.05     162.80  126128700
# 2017-09-04 163.75 164.25 158.53 158.63     157.42  101660200
# ...

# %%
df['Open'].resample('M').mean() # أخذ تكرار للسلسة الزمنية بطريقة معينة
# Out:
# Date
# 2014-09-30   100.59
# 2014-10-31   101.11
# 2014-11-30   112.09
# 2014-12-31   113.91
# 2015-01-31   110.62
# 2015-02-28   123.53
# 2015-03-31   126.45
# 2015-04-30   127.68
# 2015-05-31   129.47
# 2015-06-30   127.65
# 2015-07-31   126.01
# 2015-08-31   112.19
# 2015-09-30   113.96
# 2015-10-31   112.87
# 2015-11-30   118.08
# 2015-12-31   111.51
# 2016-01-31   100.38
# 2016-02-29    95.56
# 2016-03-31   104.06
# 2016-04-30   108.32
# 2016-05-31    94.97
# 2016-06-30    96.42
# 2016-07-31    97.27
# 2016-08-31   107.11
# 2016-09-30   109.35
# 2016-10-31   115.16
# 2016-11-30   109.84
# 2016-12-31   113.90
# 2017-01-31   118.60
# 2017-02-28   133.90
# 2017-03-31   139.50
# 2017-04-30   143.07
# 2017-05-31   151.51
# 2017-06-30   147.73
# 2017-07-31   147.66
# 2017-08-31   158.51
# 2017-09-30   158.59
# 2017-10-31   157.75
# 2017-11-30   172.80
# 2017-12-31   171.84
# 2018-01-31   173.97
# 2018-02-28   166.50
# 2018-03-31   173.74
# Freq: M, Name: Open, dtype: float64

# %%
df['Close'].resample('Q-JAN').mean()
# Out:
# Date
# 2014-10-31   102.25
# 2015-01-31   112.81
# 2015-04-30   126.13
# 2015-07-31   127.19
# 2015-10-31   113.41
# 2016-01-31   108.84
# 2016-04-30   101.98
# 2016-07-31    96.81
# 2016-10-31   111.02
# 2017-01-31   116.19
# 2017-04-30   139.84
# 2017-07-31   149.87
# 2017-10-31   159.04
# 2018-01-31   172.38
# 2018-04-30   171.01
# Freq: Q-JAN, Name: Close, dtype: float64

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd
df = pd.read_csv('AAPL.csv')
pd.options.display.float_format = '{:.2f}'.format
df
# Out:
#            Date   Open   High    Low  Close  Adj Close     Volume
# 0    2014-09-29 100.59 100.69  98.04  99.62      93.51  142718700
# 1    2014-10-06  99.95 102.38  98.31 100.73      94.56  280258200
# 2    2014-10-13 101.33 101.78  95.18  97.67      91.68  358539800
# 3    2014-10-20  98.32 105.49  98.22 105.22      98.77  358532900
# 4    2014-10-27 104.85 108.04 104.70 108.00     101.38  220230600
# ..          ...    ...    ...    ...    ...        ...        ...
# 179  2018-03-05 175.21 180.00 174.27 179.98     179.98  139852700
# 180  2018-03-12 180.29 183.50 177.62 178.02     178.02  155417500
# 181  2018-03-19 177.32 177.47 164.94 164.94     164.94  172670700
# 182  2018-03-26 168.07 175.15 165.19 167.78     167.78  157898400
# 183  2018-03-29 167.80 171.75 166.90 167.78     167.78   38398505
#
# [184 rows x 7 columns]

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.shape
# Out:
# (184, 6)

# %%
df.head()
# Out:
#     Open   High    Low  Close  Adj Close     Volume
# 0 100.59 100.69  98.04  99.62      93.51  142718700
# 1  99.95 102.38  98.31 100.73      94.56  280258200
# 2 101.33 101.78  95.18  97.67      91.68  358539800
# 3  98.32 105.49  98.22 105.22      98.77  358532900
# 4 104.85 108.04 104.70 108.00     101.38  220230600

# %%
# B = أيام العمل دون العطل 
ran = pd.date_range(start = '2019-1-1',end ='2019-9-15' ,freq='B')

# %%
ran
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14',
#                ...
#                '2019-09-02', '2019-09-03', '2019-09-04', '2019-09-05',
#                '2019-09-06', '2019-09-09', '2019-09-10', '2019-09-11',
#                '2019-09-12', '2019-09-13'],
#               dtype='datetime64[ns]', length=184, freq='B')

# %%
df.set_index(ran,inplace = True)

# %%
df.head(10)
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# 2019-01-01 100.59 100.69  98.04  99.62      93.51  142718700
# 2019-01-02  99.95 102.38  98.31 100.73      94.56  280258200
# 2019-01-03 101.33 101.78  95.18  97.67      91.68  358539800
# 2019-01-04  98.32 105.49  98.22 105.22      98.77  358532900
# 2019-01-07 104.85 108.04 104.70 108.00     101.38  220230600
# 2019-01-08 108.22 110.30 107.72 109.01     102.33  199952900
# 2019-01-09 109.02 114.19 108.40 114.18     107.65  205166700
# 2019-01-10 114.27 117.57 113.30 116.47     109.81  233414700
# 2019-01-11 116.85 119.75 116.62 118.93     112.12  181873900
# 2019-01-14 118.81 119.25 111.27 115.00     108.42  266589700

# %%
df.loc['2019-01-04':'2019-04-05']['Close'].mean()
# Out:
# 117.64924215151517

# %%
# ملئ الخلية المفقودة بالخلية غير المفقودة التى تسبقها 
df.asfreq('D', method = 'ffill') # D يومي
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# 2019-01-01 100.59 100.69  98.04  99.62      93.51  142718700
# 2019-01-02  99.95 102.38  98.31 100.73      94.56  280258200
# 2019-01-03 101.33 101.78  95.18  97.67      91.68  358539800
# 2019-01-04  98.32 105.49  98.22 105.22      98.77  358532900
# 2019-01-05  98.32 105.49  98.22 105.22      98.77  358532900
# ...           ...    ...    ...    ...        ...        ...
# 2019-09-09 175.21 180.00 174.27 179.98     179.98  139852700
# 2019-09-10 180.29 183.50 177.62 178.02     178.02  155417500
# 2019-09-11 177.32 177.47 164.94 164.94     164.94  172670700
# 2019-09-12 168.07 175.15 165.19 167.78     167.78  157898400
# 2019-09-13 167.80 171.75 166.90 167.78     167.78   38398505
#
# [256 rows x 6 columns]

# %%
# ملئ الخلية المفقودة بالخلية غير المفقودة التى تليها  
df.asfreq('W', method = 'bfill')  # W إسبوعي
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# 2019-01-06 104.85 108.04 104.70 108.00     101.38  220230600
# 2019-01-13 118.81 119.25 111.27 115.00     108.42  266589700
# 2019-01-20 108.29 113.25 104.63 112.01     105.60  283252500
# 2019-01-27 118.55 127.48 118.43 127.08     120.28  303206800
# 2019-02-03 123.88 129.25 122.87 125.90     119.16  266672900
# 2019-02-10 125.57 130.63 125.17 130.28     123.31  207440700
# 2019-02-17 132.60 132.91 129.12 130.28     123.83  198148600
# 2019-02-24 125.46 126.94 124.48 126.44     120.18  150981900
# 2019-03-03 121.50 122.57 112.10 115.52     109.80  385000600
# 2019-03-10 111.75 114.21 109.77 114.21     109.04  252662700
# 2019-03-17 112.73 112.75 109.56 111.04     106.02  184885000
# 2019-03-24 111.38 119.92 111.00 119.30     114.39  189981200
# 2019-03-31 107.28 109.00 105.57 108.03     103.58  126607800
# 2019-04-07 101.52 101.53  92.39  97.34      93.33  380336500
# ...

# %%
# periods تحديد إمتداد الفترة الزمنية 
ran = pd.date_range(start = '2020-1-1',periods=184 ,freq='B')
ran
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14',
#                ...
#                '2020-09-01', '2020-09-02', '2020-09-03', '2020-09-04',
#                '2020-09-07', '2020-09-08', '2020-09-09', '2020-09-10',
#                '2020-09-11', '2020-09-14'],
#               dtype='datetime64[ns]', length=184, freq='B')

# %%
df.set_index(ran,inplace = True)

# %%
df.head(-5)
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# 2020-01-01 100.59 100.69  98.04  99.62      93.51  142718700
# 2020-01-02  99.95 102.38  98.31 100.73      94.56  280258200
# 2020-01-03 101.33 101.78  95.18  97.67      91.68  358539800
# 2020-01-06  98.32 105.49  98.22 105.22      98.77  358532900
# 2020-01-07 104.85 108.04 104.70 108.00     101.38  220230600
# ...           ...    ...    ...    ...        ...        ...
# 2020-09-01 170.16 170.16 160.10 160.50     159.85  262992100
# 2020-09-02 159.10 163.88 150.24 156.41     155.77  317654000
# 2020-09-03 158.50 174.82 157.51 172.43     172.43  225336900
# 2020-09-04 172.05 175.65 171.01 175.50     175.50  136206400
# 2020-09-07 176.35 180.62 172.45 176.21     176.21  202128400
#
# [179 rows x 6 columns]

# %%
ran = pd.date_range(start = '2020-1-1',periods=184 ,freq='H') # H ساعي 
ran
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                ...
#                '2020-01-08 06:00:00', '2020-01-08 07:00:00',
#                '2020-01-08 08:00:00', '2020-01-08 09:00:00',
#                '2020-01-08 10:00:00', '2020-01-08 11:00:00',
#                '2020-01-08 12:00:00', '2020-01-08 13:00:00',
#                '2020-01-08 14:00:00', '2020-01-08 15:00:00'],
#               dtype='datetime64[ns]', length=184, freq='H')

# %% [markdown]
# df.set_index(ran,inplace=True)
# df

# %%
# تغير الى وقت
pd.to_datetime('1/5/2017',dayfirst = True)
# Out:
# Timestamp('2017-05-01 00:00:00')

# %%
# صيغ متعددة يقبلها باندس 
dates = ['2017-01-05 2:30:00', 'jan 5,2017 14:40','01/05/2017','2017.1.5','2017/1/5','20170105']

pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05 02:30:00', '2017-01-05 14:40:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
# جعله يتعرف على نمط معين
pd.to_datetime('1$5$2017',format='%m$%d$%Y')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
# جعله يتعرف على نمط معين
pd.to_datetime('1#5#2017',format='%m#%d#%Y')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
# تجاهل التعابير الخاطئة
dates = ['2017-01-05 2:30:00', 'jan 5,2017 14:40','01/05/2017','2017.1.5','2017/1/5','20170105','abc']
pd.to_datetime(dates,errors='ignore')
# Out:
# Index(['2017-01-05 2:30:00', 'jan 5,2017 14:40', '01/05/2017', '2017.1.5',
#        '2017/1/5', '20170105', 'abc'],
#       dtype='object')

# %%
# إستبدال التعابير الخاطئة بقيم مفقودة 
dates = ['2017-01-05 2:30:00', 'jan 5,2017 14:40','01/05/2017','2017.1.5','2017/1/5','20170105','abc']
pd.to_datetime(dates,errors='coerce')
# Out:
# DatetimeIndex(['2017-01-05 02:30:00', '2017-01-05 14:40:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                                'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %%
y = pd.Period('2016') 
y
# Out:
# Period('2016', 'A-DEC')

# %%
y.start_time
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
y.end_time
# Out:
# Timestamp('2016-12-31 23:59:59.999999999')

# %%
m = pd.Period('2011-1','M')
m
# Out:
# Period('2011-01', 'M')

# %%
m.start_time
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
m.end_time
# Out:
# Timestamp('2011-01-31 23:59:59.999999999')

# %%
m + 1
# Out:
# Period('2011-02', 'M')

# %%
d = pd.Period('2017-03-28')
d
# Out:
# Period('2017-03-28', 'D')

# %%
d + 1
# Out:
# Period('2017-03-29', 'D')

# %%
q1 = pd.Period('2017Q1')
q1
# Out:
# Period('2017Q1', 'Q-DEC')

# %%
q1 + 1
# Out:
# Period('2017Q2', 'Q-DEC')

# %%
q1 = pd.Period('2017Q1',freq = 'Q-JAN')
q1
# Out:
# Period('2017Q1', 'Q-JAN')

# %%
q1.start_time
# Out:
# Timestamp('2016-02-01 00:00:00')

# %%
q1.end_time
# Out:
# Timestamp('2016-04-30 23:59:59.999999999')

# %%
q1.asfreq('M', how='start')
# Out:
# Period('2016-02', 'M')

# %%
idx = pd.period_range('2011',periods=10,freq = 'Q-JAN')
idx
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1'],
#             dtype='period[Q-JAN]')

# %%
idx[0].start_time
# Out:
# Timestamp('2010-11-01 00:00:00')

# %%
idx[0].end_time
# Out:
# Timestamp('2011-01-31 23:59:59.999999999')

# %%
df = pd.DataFrame(data=np.random.randint(1,10,(4,5)),
                  index = ['Line time','Revenue','Expenses','Profit'],
                  columns = ['2013Q1','2013Q2','2013Q3','2013Q4','2014Q1'])

# %%
df
# Out:
#            2013Q1  2013Q2  2013Q3  2013Q4  2014Q1
# Line time       7       8       7       9       4
# Revenue         5       1       1       6       7
# Expenses        7       5       3       7       2
# Profit          7       8       5       4       3

# %%
df.loc['Line time'] = ['2013Q1','2013Q2','2013Q3','2013Q4','2014Q1']
df
# Out:
#            2013Q1  2013Q2  2013Q3  2013Q4  2014Q1
# Line time  2013Q1  2013Q2  2013Q3  2013Q4  2014Q1
# Revenue         5       1       1       6       7
# Expenses        7       5       3       7       2
# Profit          7       8       5       4       3

# %%
df = df.T
df
# Out:
#        Line time Revenue Expenses Profit
# 2013Q1    2013Q1       5        7      7
# 2013Q2    2013Q2       1        5      8
# 2013Q3    2013Q3       1        3      5
# 2013Q4    2013Q4       6        7      4
# 2014Q1    2014Q1       7        2      3

# %%
df.drop('Line time',axis = 1,inplace = True)

# %%
df
# Out:
#        Revenue Expenses Profit
# 2013Q1       5        7      7
# 2013Q2       1        5      8
# 2013Q3       1        3      5
# 2013Q4       6        7      4
# 2014Q1       7        2      3

# %%
df.index.name = 'Line time'

# %%
df
# Out:
#           Revenue Expenses Profit
# Line time
# 2013Q1          5        7      7
# 2013Q2          1        5      8
# 2013Q3          1        3      5
# 2013Q4          6        7      4
# 2014Q1          7        2      3

# %%
df.index = pd.PeriodIndex(df.index,freq = 'Q-JAN')
df
# Out:
#           Revenue Expenses Profit
# Line time
# 2013Q1          5        7      7
# 2013Q2          1        5      8
# 2013Q3          1        3      5
# 2013Q4          6        7      4
# 2014Q1          7        2      3

# %%
df.index
# Out:
# PeriodIndex(['2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1'], dtype='period[Q-JAN]', name='Line time')

# %%
df['start data'] = df.index.map(lambda x:x.start_time)
df
# Out:
#           Revenue Expenses Profit start data
# Line time
# 2013Q1          5        7      7 2012-02-01
# 2013Q2          1        5      8 2012-05-01
# 2013Q3          1        3      5 2012-08-01
# 2013Q4          6        7      4 2012-11-01
# 2014Q1          7        2      3 2013-02-01

# %%
df['end data'] = df.index.map(lambda x:x.end_time)
df
# Out:
#           Revenue Expenses Profit start data                      end data
# Line time
# 2013Q1          5        7      7 2012-02-01 2012-04-30 23:59:59.999999999
# 2013Q2          1        5      8 2012-05-01 2012-07-31 23:59:59.999999999
# 2013Q3          1        3      5 2012-08-01 2012-10-31 23:59:59.999999999
# 2013Q4          6        7      4 2012-11-01 2013-01-31 23:59:59.999999999
# 2014Q1          7        2      3 2013-02-01 2013-04-30 23:59:59.999999999

# %%
df = pd.DataFrame([72.38,71.00,71.67,72.80,73.00,72.50],
                  index=['2017-8-17 09:00:00','2017-8-17 09:15:00','2017-8-17 09:30:00','2017-8-17 10:00:00'
                         ,'2017-8-17 10:30:00','2017-8-17 11:00:00']
                 ,columns=['price'])

# %%
df.index.name = 'Date Time'

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00', '2017-08-17 09:15:00',
#                '2017-08-17 09:30:00', '2017-08-17 10:00:00',
#                '2017-08-17 10:30:00', '2017-08-17 11:00:00'],
#               dtype='datetime64[ns]', name='Date Time', freq=None)

# %%
df = pd.DataFrame([172.38,171.00,171.67,172.80,173.00,172.50,166.32,167.42,169.64,168.71],
                  index=['2017-8-15','2017-8-16','2017-8-17','2017-8-18'
                         ,'2017-8-19','2017-8-20','2017-8-21','2017-8-22','2017-8-23','2017-8-24']
                 ,columns=['price'])

# %%
df.index.name = 'Date'
df
# Out:
#            price
# Date
# 2017-8-15 172.38
# 2017-8-16 171.00
# 2017-8-17 171.67
# 2017-8-18 172.80
# 2017-8-19 173.00
# 2017-8-20 172.50
# 2017-8-21 166.32
# 2017-8-22 167.42
# 2017-8-23 169.64
# 2017-8-24 168.71

# %%
df.shift(2)
# Out:
#            price
# Date
# 2017-8-15    NaN
# 2017-8-16    NaN
# 2017-8-17 172.38
# 2017-8-18 171.00
# 2017-8-19 171.67
# 2017-8-20 172.80
# 2017-8-21 173.00
# 2017-8-22 172.50
# 2017-8-23 166.32
# 2017-8-24 167.42

# %%
df.shift(-2)
# Out:
#            price
# Date
# 2017-8-15 171.67
# 2017-8-16 172.80
# 2017-8-17 173.00
# 2017-8-18 172.50
# 2017-8-19 166.32
# 2017-8-20 167.42
# 2017-8-21 169.64
# 2017-8-22 168.71
# 2017-8-23    NaN
# 2017-8-24    NaN

# %%
df['prev_day_price'] = df['price'].shift(1)
df
# Out:
#            price  prev_day_price
# Date
# 2017-8-15 172.38             NaN
# 2017-8-16 171.00          172.38
# 2017-8-17 171.67          171.00
# 2017-8-18 172.80          171.67
# 2017-8-19 173.00          172.80
# 2017-8-20 172.50          173.00
# 2017-8-21 166.32          172.50
# 2017-8-22 167.42          166.32
# 2017-8-23 169.64          167.42
# 2017-8-24 168.71          169.64

# %%
df['1 day change'] = df['price'] - df['prev_day_price']
df
# Out:
#            price  prev_day_price  1 day change
# Date
# 2017-8-15 172.38             NaN           NaN
# 2017-8-16 171.00          172.38         -1.38
# 2017-8-17 171.67          171.00          0.67
# 2017-8-18 172.80          171.67          1.13
# 2017-8-19 173.00          172.80          0.20
# 2017-8-20 172.50          173.00         -0.50
# 2017-8-21 166.32          172.50         -6.18
# 2017-8-22 167.42          166.32          1.10
# 2017-8-23 169.64          167.42          2.22
# 2017-8-24 168.71          169.64         -0.93

# %%
df['5 day % return'] = (df['price'] - df['price'].shift(5)) * 100 / df['price']
df
# Out:
#            price  prev_day_price  1 day change  5 day % return
# Date
# 2017-8-15 172.38             NaN           NaN             NaN
# 2017-8-16 171.00          172.38         -1.38             NaN
# 2017-8-17 171.67          171.00          0.67             NaN
# 2017-8-18 172.80          171.67          1.13             NaN
# 2017-8-19 173.00          172.80          0.20             NaN
# 2017-8-20 172.50          173.00         -0.50            0.07
# 2017-8-21 166.32          172.50         -6.18           -2.81
# 2017-8-22 167.42          166.32          1.10           -2.54
# 2017-8-23 169.64          167.42          2.22           -1.86
# 2017-8-24 168.71          169.64         -0.93           -2.54

# %%
df = df[['price']]

# %%
df
# Out:
#            price
# Date
# 2017-8-15 172.38
# 2017-8-16 171.00
# 2017-8-17 171.67
# 2017-8-18 172.80
# 2017-8-19 173.00
# 2017-8-20 172.50
# 2017-8-21 166.32
# 2017-8-22 167.42
# 2017-8-23 169.64
# 2017-8-24 168.71

# %%
df.index
# Out:
# Index(['2017-8-15', '2017-8-16', '2017-8-17', '2017-8-18', '2017-8-19',
#        '2017-8-20', '2017-8-21', '2017-8-22', '2017-8-23', '2017-8-24'],
#       dtype='object', name='Date')

# %%
df.index= pd.date_range(start='2017-08-15',periods=10,freq='B')
df.index
# Out:
# DatetimeIndex(['2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#                '2017-08-21', '2017-08-22', '2017-08-23', '2017-08-24',
#                '2017-08-25', '2017-08-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
df
# Out:
#             price
# 2017-08-15 172.38
# 2017-08-16 171.00
# 2017-08-17 171.67
# 2017-08-18 172.80
# 2017-08-21 173.00
# 2017-08-22 172.50
# 2017-08-23 166.32
# 2017-08-24 167.42
# 2017-08-25 169.64
# 2017-08-28 168.71

# %%
df.tshift(2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21628\1351961431.py:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   df.tshift(2)
#             price
# 2017-08-17 172.38
# 2017-08-18 171.00
# 2017-08-21 171.67
# 2017-08-22 172.80
# 2017-08-23 173.00
# 2017-08-24 172.50
# 2017-08-25 166.32
# 2017-08-28 167.42
# 2017-08-29 169.64
# 2017-08-30 168.71

# %%
df.tshift(-2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21628\3812926083.py:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   df.tshift(-2)
#             price
# 2017-08-11 172.38
# 2017-08-14 171.00
# 2017-08-15 171.67
# 2017-08-16 172.80
# 2017-08-17 173.00
# 2017-08-18 172.50
# 2017-08-21 166.32
# 2017-08-22 167.42
# 2017-08-23 169.64
# 2017-08-24 168.71
