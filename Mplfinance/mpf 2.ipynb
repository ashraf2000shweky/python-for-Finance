# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import pandas_ta as ta
import talib as tb
import mplfinance as mpf

# %%
data = pd.read_csv('AAPL.csv',index_col='Date',parse_dates=['Date'])

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ...                ...         ...         ...         ...         ...
# 2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#                Volume
# Date
# 2014-09-29  142718700
# 2014-10-06  280258200
# 2014-10-13  358539800
# ...

# %%
mpf.plot(data,volume=True,type ='candle',tight_layout=True,figscale=1)

# %%
fig,ax =  plt.subplots(nrows=2,ncols=1)
mpf.plot(data,tight_layout=True,type ='candle',style='yahoo',ax=ax[0],volume=ax[1])
plt.tight_layout()

# %%
df = pd.DataFrame()
data0 = df.ta.ticker('aapl',period='1y',interval='1d')
data0
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-12-29 00:00:00-05:00  178.295210  179.587712  177.112075  178.344925
# 2021-12-30 00:00:00-05:00  178.434414  179.528072  177.062372  177.171738
# 2021-12-31 00:00:00-05:00  177.062353  178.195774  176.237140  176.545364
# 2022-01-03 00:00:00-05:00  176.803874  181.824737  176.684572  180.959747
# 2022-01-04 00:00:00-05:00  181.576172  181.884380  178.086416  178.663071
# ...                               ...         ...         ...         ...
# 2022-12-22 00:00:00-05:00  134.350006  134.559998  130.300003  132.229996
# 2022-12-23 00:00:00-05:00  130.919998  132.419998  129.639999  131.860001
# 2022-12-27 00:00:00-05:00  131.380005  131.410004  128.720001  130.029999
# 2022-12-28 00:00:00-05:00  129.669998  131.029999  125.870003  126.040001
# 2022-12-29 00:00:00-05:00  127.989998  130.479996  127.815002  130.054993
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df = pd.DataFrame()
data1 = df.ta.ticker('goog',period='1y',interval='1d')
data1
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-12-29 00:00:00-05:00  146.429504  147.183746  145.504501  146.504501
# 2021-12-30 00:00:00-05:00  146.449997  147.062500  145.758499  146.002502
# 2021-12-31 00:00:00-05:00  145.544006  146.365005  144.677505  144.679504
# 2022-01-03 00:00:00-05:00  144.475494  145.550003  143.502502  145.074493
# 2022-01-04 00:00:00-05:00  145.550507  146.610001  143.816147  144.416504
# ...                               ...         ...         ...         ...
# 2022-12-22 00:00:00-05:00   88.930000   89.180000   86.940002   88.260002
# 2022-12-23 00:00:00-05:00   87.620003   90.099998   87.620003   89.809998
# 2022-12-27 00:00:00-05:00   89.309998   89.500000   87.535004   87.930000
# 2022-12-28 00:00:00-05:00   87.500000   88.519997   86.370003   86.459999
# 2022-12-29 00:00:00-05:00   87.029999   89.105003   86.989998   88.949997
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df = pd.DataFrame()
data2 = df.ta.ticker('META',period='1y',interval='1d')
data2
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-12-29 00:00:00-05:00  346.910004  349.690002  341.640015  342.940002
# 2021-12-30 00:00:00-05:00  344.000000  347.230011  343.220001  344.359985
# 2021-12-31 00:00:00-05:00  343.019989  343.440002  336.269989  336.350006
# 2022-01-03 00:00:00-05:00  338.299988  341.079987  337.190002  338.540009
# 2022-01-04 00:00:00-05:00  339.950012  343.089996  331.869995  336.529999
# ...                               ...         ...         ...         ...
# 2022-12-22 00:00:00-05:00  117.199997  118.620003  114.379997  117.120003
# 2022-12-23 00:00:00-05:00  116.029999  118.180000  115.540001  118.040001
# 2022-12-27 00:00:00-05:00  117.930000  118.599998  116.050003  116.879997
# 2022-12-28 00:00:00-05:00  116.250000  118.150002  115.510002  115.620003
# 2022-12-29 00:00:00-05:00  116.400002  120.169998  115.769997  119.929497
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
fig,ax =  plt.subplots(nrows=2,ncols=3,figsize=(9,6))
mpf.plot(data0,type='candle',ax=ax[0][0],volume=ax[1][0],mav=(10,20),axtitle='AAPL')
mpf.plot(data1,type='candle',ax=ax[0][1],volume=ax[1][1],mav=(10,20),axtitle='GOOG')
mpf.plot(data2 ,type='candle',ax=ax[0][2],volume=ax[1][2],mav=(10,20),axtitle='FB')
plt.tight_layout()

# %%
fig,ax =  plt.subplots(nrows=2,ncols=1)
ax[0].tick_params(labelsize=10)
ax[1].tick_params(labelsize=10)
ap = mpf.make_addplot(data[['High','Low']],ax=ax[0],ylabel='Bollinger Bands')
mpf.plot(data,style='blueskies',ax=ax[0],volume=ax[1],addplot=ap,xrotation=10,type='candle')
ax[0].legend(labels=['_nolegend_','_nolegend_','High','Low']) # حركة جميلة 
plt.tight_layout()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4780\853175156.py:6: UserWarning: The handle <matplotlib.collections.LineCollection object at 0x000001DCDD5F9DC0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax[0].legend(labels=['_nolegend_','_nolegend_','High','Low']) # حركة جميلة
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4780\853175156.py:6: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x000001DCDD5F9DF0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax[0].legend(labels=['_nolegend_','_nolegend_','High','Low']) # حركة جميلة

# %%
df = pd.DataFrame()
data = df.ta.ticker('aapl',period='1y',interval='1d')
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-12-29 00:00:00-05:00  178.295210  179.587712  177.112075  178.344925
# 2021-12-30 00:00:00-05:00  178.434414  179.528072  177.062372  177.171738
# 2021-12-31 00:00:00-05:00  177.062368  178.195789  176.237156  176.545380
# 2022-01-03 00:00:00-05:00  176.803859  181.824722  176.684557  180.959732
# 2022-01-04 00:00:00-05:00  181.576187  181.884396  178.086431  178.663086
# ...                               ...         ...         ...         ...
# 2022-12-22 00:00:00-05:00  134.350006  134.559998  130.300003  132.229996
# 2022-12-23 00:00:00-05:00  130.919998  132.419998  129.639999  131.860001
# 2022-12-27 00:00:00-05:00  131.380005  131.410004  128.720001  130.029999
# 2022-12-28 00:00:00-05:00  129.669998  131.029999  125.870003  126.040001
# 2022-12-29 00:00:00-05:00  127.989998  130.479996  127.815002  130.089996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
mpf.plot(data,hlines=[170,150])

# %%
mpf.plot(data,hlines=dict(hlines=[170,150],
                          colors=['gray','gray'],linestyle='--',linewidths=(1,2)))
mpf.plot(data,hlines=dict(hlines=[170,150],
                          colors=['gray','gray'],linestyle='--',linewidths=(1,2)),type='candle')

# %%
mpf.plot(data,type='candle',
vlines=dict(vlines=['2022-2-06','2022-5-15','2022-7-25'],linewidths=(1,2,3),linestyle='--'))

# %%
mpf.plot(data,type='candle',vlines=dict(vlines='2022-5-18',linewidths=125,alpha=0.4))

# %%
mpf.plot(data, type='candle', volume=True, mav=(3, 7, 13),figsize=(20,10), savefig='123.png')

# %%
df = data.loc['2022-07-01':'2022-12-30',:]

# %%
mpf.plot(df,hlines=[170,150],type ='candle' )

# %%
added_plots =  [ mpf.make_addplot(data['High']),
                mpf.make_addplot(data['Low']),
                mpf.make_addplot(data['Open']),
                mpf.make_addplot(data['Close']) 
               ]



fig, axes = mpf.plot(data, type="candle",
                     addplot=added_plots,
                     volume=True,
                     returnfig=True)
                     

axes[0].set_ylabel("AAPL")
axes[2].set_ylabel("Volume AAPL")
axes[0].legend(['_nolegend_','_nolegend_','High','Low','Open','Close'])
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4780\3478886564.py:17: UserWarning: The handle <matplotlib.collections.LineCollection object at 0x000001DCE0A4E520> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   axes[0].legend(['_nolegend_','_nolegend_','High','Low','Open','Close'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4780\3478886564.py:17: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x000001DCE0A4E550> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   axes[0].legend(['_nolegend_','_nolegend_','High','Low','Open','Close'])

# %%
data['macd'], data['macdsignal'], data['macdhist'] =tb.MACD(data['Close'], fastperiod=12, slowperiod=26,signalperiod=9)

# %%
fig , ax =plt.subplots(3,1,sharex=True,figsize=(10,10),gridspec_kw= {'height_ratios':[3,2,2]})

fig.set_edgecolor('k')
fig.set_linewidth(4)
fig.set_facecolor('cyan')
ax3 = ax[2].twinx()

p2 = [ mpf.make_addplot(data['High'],color='g',ax=ax[2]),  
       mpf.make_addplot(data['Low'],color='b',ax=ax[2]),
       mpf.make_addplot(data['macd'],ax=ax3,color='r')] 
                         
                         
mpf.plot(data,type='candle',ax=ax[0], addplot=p2 ,style='blueskies',volume=ax[1],mav=(6,9))
fig.suptitle('AAPL')

ax[0].legend(labels=['_nolegend_','_nolegend_','mav6','mav9'])
ax[2].legend(['High','Low'])
ax3.legend(['MACD'],bbox_to_anchor=[0.7,0.2])
ax[2].grid(False)
ax[0].set_ylabel('Price',fontsize=15,labelpad=30,color='r')
ax[1].set_ylabel('Volume',fontsize=10,labelpad=35,color='r')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4780\3340810109.py:16: UserWarning: The handle <matplotlib.collections.LineCollection object at 0x000001DCDC092C10> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax[0].legend(labels=['_nolegend_','_nolegend_','mav6','mav9'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4780\3340810109.py:16: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x000001DCDC092BE0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax[0].legend(labels=['_nolegend_','_nolegend_','mav6','mav9'])
